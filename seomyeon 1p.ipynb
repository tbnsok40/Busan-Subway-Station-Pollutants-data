# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["font.weight"] = 'bold'


nampo = pd.read_csv('서면1p.csv', encoding = 'cp949')
nampo
# Out:
#        year  month  day  hour  CO (ppm)  CO2 (ppm)  NO2 (ppm)  PM2.5 (μg/m³)  \
# 0      2019      1    1     0       0.5      493.0      0.034           14.0
# 1      2019      1    1     1       0.5      479.0      0.030           13.0
# 2      2019      1    1     2       0.5      458.0      0.029           13.0
# 3      2019      1    1     3       0.5      457.0      0.028           18.0
# 4      2019      1    1     4       0.4      453.0      0.032           18.0
# ...     ...    ...  ...   ...       ...        ...        ...            ...
# 52579  2014     12   31    19       0.4      554.0      0.040           19.0
# 52580  2014     12   31    20       0.5      574.0      0.038           13.0
# 52581  2014     12   31    21       0.5      548.0      0.037           19.0
# 52582  2014     12   31    22       0.6      557.0      0.037           24.0
# 52583  2014     12   31    23       0.5      512.0      0.030           21.0
#
#        PM10 (μg/m³)  HCHO (ppm)
# 0              29.0         NaN
# 1              31.0         NaN
# 2              29.0         NaN
# 3              25.0         NaN
# 4              27.0         NaN
# ...             ...         ...
# 52579          53.0         NaN
# 52580          39.0         NaN
# 52581          53.0         NaN
# 52582          61.0         NaN
# 52583          53.0         NaN
#
# [52584 rows x 10 columns]

# %%
def automate_alltime(df):
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM10 (μg/m³)", data=df, ax= ax1, color = 'w')
    ax1.set(ylim=(-10, 300)) ## 750위로 9개 점(5개년에 걸쳐)
    plt.show()

    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM2.5 (μg/m³)", data=df, ax= ax1, color = 'w')
    ax1.set(ylim=(-10, 200)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    return

def automate_separate(df):
    
    df['OP'] = 'OP'
    df.loc[(df['hour']<=5)&(df['hour']>=1), 'OP'] = 'NON'
    
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)

    sns.boxplot(x="year", y="PM10 (μg/m³)", data=nampo, ax= ax1, hue = nampo['OP'])
    ax1.set(ylim=(-10, 300)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    
    
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM2.5 (μg/m³)", data=nampo, ax= ax1, hue = nampo['OP'])
    ax1.set(ylim=(-10, 200)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    
 
    return

automate_alltime(nampo)
automate_separate(nampo)
