plt.rcParams["figure.figsize"] = (20,9)

sm2.plot()

# %%
op = pd.read_csv('C:/codeit/op.csv')
op
# Out:
#    Unnamed: 0 Unnamed: 1     2014     2015     2016     2017     2018     2019
# 0          CO      N-1-W    0.653    0.533    0.434    0.454    0.483    0.495
# 1          CO     SS-2-W    0.654    0.562    0.459    0.418    0.362    0.412
# 2          CO      S-1-W    0.784    0.547    0.629    0.552    0.570    0.490
# 3          CO      S-2-W    0.598    0.465    0.492    0.421    0.392    0.459
# 4          CO      S-1-P    0.735    0.542    0.523    0.454    0.480    0.474
# 5          CO      S-2-P    0.540    0.475    0.496    0.488    0.479    0.478
# 6         CO2      N-1-W  536.346  547.575  567.263  575.465  558.925  517.430
# 7         CO2     SS-2-W  506.417  524.711  539.825  550.636  533.789  531.412
# 8         CO2      S-1-W  600.864  554.083  684.408  657.368  640.838  600.044
# 9         CO2      S-2-W  660.518  576.070  656.026  654.820  611.281  604.645
# 10        CO2      S-1-P  554.452  636.522  577.425  562.399  540.632  544.693
# 11        CO2      S-2-P  564.592  642.171  566.728  561.215  570.904  565.974
# 12        NO2      N-1-W    0.042    0.041    0.045    0.042    0.038    0.035
# 13        NO2     SS-2-W    0.037    0.041    0.043    0.051    0.039    0.034
# 14        NO2      S-1-W    0.049    0.041    0.041    0.045    0.040    0.040
# 15        NO2      S-2-W    0.043    0.046    0.045    0.047    0.042    0.041
# 16        NO2      S-1-P    0.042    0.039    0.043    0.047    0.047    0.037
# 17        NO2      S-2-P    0.051    0.039    0.052    0.050    0.048    0.041
# 18       PM10      N-1-W   51.794   53.671   46.118   44.061   46.961   42.605
# 19       PM10     SS-2-W   38.904   37.741   32.522   32.947   31.522   35.908
# 20       PM10      S-1-W   59.224   54.803   49.807   47.750   44.939   44.539
# 21       PM10      S-2-W   45.939   46.259   47.009   41.974   40.491   41.057
# 22       PM10      S-1-P   55.877   53.632   54.838   46.737   40.728   40.329
# 23       PM10      S-2-P   50.750   48.031   41.838   38.868   33.610   36.285
# 24      PM2.5      N-1-W   25.772   25.982   24.268   26.162   27.649   27.395
# 25      PM2.5     SS-2-W   20.991   21.838   16.219   13.991   19.474   21.531
# 26      PM2.5      S-1-W   35.105   26.404   28.092   28.706   26.592   21.443
# 27      PM2.5      S-2-W   29.553   23.246   28.566   24.127   23.325   20.939
# 28      PM2.5      S-1-P   29.851   30.596   31.386   25.228   21.943   21.154
# 29      PM2.5      S-2-P   24.408   27.408   30.285   25.443   23.149   19.465
# 30       HCHO      N-1-W    8.912    8.046   18.205    8.760    7.409    4.055
# 31       HCHO     SS-2-W    7.161    8.086    7.088    8.136    7.989    6.740
# 32       HCHO      S-2-W   10.495    6.398    5.864    6.817    3.232    1.994

# %% [markdown]
# # CO

# %%
op1=op[['Unnamed: 1','2014','2015','2016','2017','2018','2019']]
op_co = op1.loc[0:5, 'Unnamed: 1': '2019']
op_co = op_co.set_index('Unnamed: 1')
op_co = op_co.T
op_co.plot()
plt.title("CO")
plt.xlabel("Year")
plt.ylabel("Concenturation")
plt.rcParams["figure.figsize"] = (20,8)
ax1 = plt.show()
ax1

# %% [markdown]
# # CO2

# %%
op_co2=op[['Unnamed: 1','2014','2015','2016','2017','2018','2019']]
op_co2 = op_co2.loc[6:11, 'Unnamed: 1': '2019']
op_co2 = op_co2.set_index('Unnamed: 1')
op_co2 = op_co2.T
op_co2.plot()
plt.title("CO2")
plt.xlabel("Year")
plt.ylabel("Concenturation")
plt.rcParams["figure.figsize"] = (20,8)
ax2 = plt.show()

# %% [markdown]
# # NO2

# %%
op_no2=op[['Unnamed: 1','2014','2015','2016','2017','2018','2019']]
op_no2 = op_no2.loc[12:17, 'Unnamed: 1': '2019']
op_no2 = op_no2.set_index('Unnamed: 1')
op_no2 = op_no2.T
op_no2.plot()
plt.title("NO2")
plt.xlabel("Year")
plt.ylabel("Concenturation")
plt.rcParams["figure.figsize"] = (20,8)
ax3 = plt.show()

# %% [markdown]
# # PM10

# %%
op_PM10=op[['Unnamed: 1','2014','2015','2016','2017','2018','2019']]
op_PM10 = op_PM10.loc[18:23, 'Unnamed: 1': '2019']
op_PM10 = op_PM10.set_index('Unnamed: 1')
op_PM10 = op_PM10.T
op_PM10.plot()
plt.title("PM10")
plt.xlabel("Year")
plt.ylabel("Concenturation")
plt.rcParams["figure.figsize"] = (20,8)
ax4 = plt.show()

# %% [markdown]
# # PM2.5

# %%
op_PM25=op[['Unnamed: 1','2014','2015','2016','2017','2018','2019']]
op_PM25 = op_PM25.loc[24:29, 'Unnamed: 1': '2019']
op_PM25 = op_PM25.set_index('Unnamed: 1')
op_PM25 = op_PM25.T
op_PM25.plot()
plt.title("PM2.5")
plt.xlabel("Year")
plt.ylabel("Concenturation")
plt.rcParams["figure.figsize"] = (20,8)
ax5 = plt.show()

# %% [markdown]
# # HCHO

# %%
op_hcho=op[['Unnamed: 1','2014','2015','2016','2017','2018','2019']]
op_hcho = op_hcho.loc[30:33, 'Unnamed: 1': '2019']
op_hcho = op_hcho.set_index('Unnamed: 1')
op_hcho = op_hcho.T
op_hcho.plot()
plt.title("HCHO")
plt.xlabel("Year")
plt.ylabel("Concenturation")
plt.rcParams["figure.figsize"] = (20,8)
ax6 = plt.show()

# %%
op_co2 = op_co2.T
op_co2
# Out:
#              2014   2015   2016   2017   2018   2019
# Unnamed: 1
# N-1-W       0.042  0.041  0.045  0.042  0.038  0.035
# SS-2-W      0.037  0.041  0.043  0.051  0.039  0.034
# S-1-W       0.049  0.041  0.041  0.045  0.040  0.040
# S-2-W       0.043  0.046  0.045  0.047  0.042  0.041
# S-1-P       0.042  0.039  0.043  0.047  0.047  0.037
# S-2-P       0.051  0.039  0.052  0.050  0.048  0.041

# %%
# figure, ((ax1, ax2, ax3), (ax4,ax5,ax6)) = plt.subplots(nrows=2, ncols=3)

figure, ((ax1, ax2), (ax3, ax4), (ax5,ax6)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(18,18)

# figure, ax1 = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(20,8)
# sns.lineplot(data=op_co)

# figure, ax2 = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(20,8)
# sns.lineplot(data=op_co2)

# figure, ax3 = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(20,8)
# sns.lineplot(data=op_no2)

# figure, ax4 = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(20,8)
# sns.lineplot(data=op_PM25)

# figure, ax5 = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(20,8)
# sns.lineplot(data=op_PM10)

# figure, ax6 = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(20,8)
# sns.lineplot(data=op_hcho)


sns.lineplot(data = op_co, ax= ax1)
sns.lineplot(data = op_co2, ax= ax2)
sns.lineplot(data = op_no2, ax= ax3)
sns.lineplot(data = op_PM25,ax= ax4)
sns.lineplot(data = op_PM10, ax= ax5)
sns.lineplot(data = op_hcho,ax= ax6)

ax1.set_title('CO')
ax1.set_xlabel('year')
ax1.set_ylabel('Concentration')

ax2.set_title('CO2')
ax2.set_xlabel('year')
ax2.set_ylabel('Concentration')

ax3.set_title('NO2')
ax3.set_xlabel('year')
ax3.set_ylabel('Concentration')

ax4.set_title('PM25')
ax4.set_xlabel('year')
ax4.set_ylabel('Concentration')

ax5.set_title('PM10')
ax5.set_xlabel('year')
ax5.set_ylabel('Concentration')

ax6.set_title('HCCO')
ax6.set_xlabel('year')
ax6.set_ylabel('Concentration')

# elements = ['CO','CO2','NO2','PM2.5','PM10','HCHO']
# Out:
# Text(0, 0.5, 'Concentration')

# %%
non_op = pd.read_csv('C:/codeit/non_op.csv')
non_op
# Out:
#    Unnamed: 0 Unnamed: 1     2014     2015     2016     2017     2018     2019
# 0          CO      N-1-W    0.537    0.450    0.365    0.370    0.410    0.430
# 1          CO     SS-2-W    0.583    0.510    0.413    0.378    0.325    0.375
# 2          CO      S-1-W    0.675    0.475    0.528    0.467    0.498    0.432
# 3          CO      S-2-W    0.510    0.415    0.397    0.355    0.330    0.417
# 4          CO      S-1-P    0.660    0.445    0.442    0.393    0.442    0.435
# 5          CO      S-2-P    0.488    0.395    0.437    0.427    0.427    0.432
# 6         CO2      N-1-W  424.250  425.750  441.483  460.450  450.467  420.767
# 7         CO2     SS-2-W  437.100  447.383  455.267  459.567  442.467  428.983
# 8         CO2      S-1-W  456.867  442.900  470.317  445.467  423.283  406.283
# 9         CO2      S-2-W  448.283  448.000  448.550  439.000  446.767  445.483
# 10        CO2      S-1-P  443.367  455.383  445.967  455.417  444.717  496.183
# 11        CO2      S-2-P  445.050  432.550  437.050  447.133  456.800  439.317
# 12        NO2      N-1-W    0.030    0.030    0.031    0.028    0.026    0.024
# 13        NO2     SS-2-W    0.024    0.025    0.027    0.032    0.024    0.023
# 14        NO2      S-1-W    0.033    0.025    0.028    0.031    0.028    0.029
# 15        NO2      S-2-W    0.028    0.032    0.029    0.031    0.029    0.028
# 16        NO2      S-1-P    0.029    0.026    0.028    0.030    0.032    0.027
# 17        NO2      S-2-P    0.036    0.024    0.032    0.032    0.031    0.029
# 18       PM10      N-1-W   38.633   42.300   33.867   28.850   32.133   29.267
# 19       PM10     SS-2-W   41.283   36.850   31.717   30.133   28.333   29.067
# 20       PM10      S-1-W   52.883   61.783   38.900   35.617   30.883   30.317
# 21       PM10      S-2-W   52.750   45.650   35.033   33.450   33.883   30.200
# 22       PM10      S-1-P   43.533   45.917   38.133   31.700   29.467   28.600
# 23       PM10      S-2-P   52.600   48.783   32.950   31.183   30.400   28.333
# 24      PM2.5      N-1-W   22.933   24.533   22.900   20.167   22.267   21.767
# 25      PM2.5     SS-2-W   23.767   24.167   17.950   15.167   19.950   21.250
# 26      PM2.5      S-1-W   31.617   28.883   23.583   28.833   27.467   18.133
# 27      PM2.5      S-2-W   35.867   24.717   29.933   22.500   29.217   19.500
# 28      PM2.5      S-1-P   25.833   28.133   24.150   18.917   18.817   17.783
# 29      PM2.5      S-2-P   25.750   30.033   29.817   23.483   22.333   18.117
# 30       HCHO      N-1-W    7.680    7.325   15.638    7.803    6.465    3.290
# 31       HCHO     SS-2-W    6.285    7.350    6.707    7.800    7.473    6.153
# 32       HCHO      S-2-W    8.218    5.063    4.632    5.703    2.670    1.602
