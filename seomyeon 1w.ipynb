# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["font.weight"] = 'bold'


nampo = pd.read_csv('서면1w.csv', encoding = 'cp949')
nampo
# Out:
#        year  month  day  hour  CO (ppm)  CO2 (ppm)  NO2 (ppm)  PM2.5 (μg/m³)  \
# 0      2019      1    1     0       0.5      501.0      0.033           22.0
# 1      2019      1    1     1       0.5      494.0      0.028           18.0
# 2      2019      1    1     2       0.5      429.0      0.027           24.0
# 3      2019      1    1     3       0.5      428.0      0.027           18.0
# 4      2019      1    1     4       0.5      431.0      0.031           15.0
# ...     ...    ...  ...   ...       ...        ...        ...            ...
# 52579  2014     12   31    19       0.5      639.0      0.044           29.0
# 52580  2014     12   31    20       0.5      643.0      0.043           23.0
# 52581  2014     12   31    21       0.5      618.0      0.042           33.0
# 52582  2014     12   31    22       0.5      613.0      0.041           32.0
# 52583  2014     12   31    23       0.4      559.0      0.034           26.0
#
#        PM10 (μg/m³)  HCHO (ppm)
# 0              30.0         NaN
# 1              31.0         NaN
# 2              23.0         NaN
# 3              19.0         NaN
# 4              25.0         NaN
# ...             ...         ...
# 52579          47.0         NaN
# 52580          40.0         NaN
# 52581          50.0         NaN
# 52582          49.0         NaN
# 52583          42.0         NaN
#
# [52584 rows x 10 columns]

# %%
def automate_alltime(df):
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM10 (μg/m³)", data=df, ax= ax1, color = 'w')
    ax1.set(ylim=(-10, 300)) ## 750위로 9개 점(5개년에 걸쳐)
    plt.show()

    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM2.5 (μg/m³)", data=df, ax= ax1, color = 'w')
    ax1.set(ylim=(-10, 200)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    return

def automate_separate(df):
    
    df['OP'] = 'OP'
    df.loc[(df['hour']<=5)&(df['hour']>=1), 'OP'] = 'NON'
    
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)

    sns.boxplot(x="year", y="PM10 (μg/m³)", data=nampo, ax= ax1, hue = nampo['OP'])
    ax1.set(ylim=(-10, 300)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    
    
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM2.5 (μg/m³)", data=nampo, ax= ax1, hue = nampo['OP'])
    ax1.set(ylim=(-10, 200)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    
 
    return

automate_alltime(nampo)
automate_separate(nampo)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# plt.title("요일 별 전체 팁의 Box Plot")
fig, (ax1) = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(18,10)
sns.boxplot(x="datetime-year", y="PM10", data=nampo, ax= ax1)
ax1.set(ylim=(-10, 300)) ## 600위로 2개 점

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# plt.title("요일 별 전체 팁의 Box Plot")
fig, (ax1) = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(18,10)
sns.boxplot(x="datetime-year", y="PM2.5", data=nampo, ax= ax1)
ax1.set(ylim=(-10, 200)) ## 800위로 10개 점 (4개년에 걸쳐)

plt.show()
