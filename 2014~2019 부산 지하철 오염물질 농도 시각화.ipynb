# %%
import pandas as pd
import matplotlib as pyplot
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv('C:/codeit/200512_지하철.csv',index_col=0)

# %%
df.dtypes
df
# Out:
#         N-1-W  SS-2-W   S-1-W   S-2-W   S-1-P   S-2-P    CO.1
# CO
# 2014   629.9   642.7   764.3   582.6   717.6   528.2   644.2
# 2015   509.7   549.8   521.9   458.3   529.0   452.8   503.6
# 2016   420.9   451.6   605.8   469.7   506.6   483.8   489.7
# 2017   430.3   404.6   520.5   403.7   428.5   466.7   442.4
# 2018   461.4   342.7   362.7   362.7   455.5   457.3   407.0
# 2019   474.8   398.1   468.2   443.8   459.3   459.3   450.6
# CO2     N-1-W  SS-2-W   S-1-W   S-2-W   S-1-P   S-2-P     CO2
# 2014   512.6   492.2   570.2   615.6   531.1   539.5   543.5
# 2015   522.0   508.8   598.2   551.0   530.5   548.6   543.2
# 2016   541.1   522.7   639.4   611.1   549.3   539.7   567.2
# 2017   542.5   521.7   599.2   597.6   529.2   528.1   553.0
# 2018   518.3   505.7   561.3   561.3   510.1   536.7   532.3
# 2019   479.2   503.8   549.0   563.5   526.7   531.5   525.6
# NO2     N-1-W  SS-2-W   S-1-W   S-2-W   S-1-P   S-2-P     NO2
# ...

# %%
df_CO = df.iloc[0:6,0:6]
df_CO2 = df.iloc[7:13,0:6]
df_NO2 = df.iloc[14:20,0:6]
df_PM10 = df.iloc[21:27,0:6]
df_PM25 = df.iloc[28:34,0:6]

# %%
df_CO
# Out:
#        N-1-W  SS-2-W   S-1-W   S-2-W   S-1-P   S-2-P
# CO
# 2014  629.9   642.7   764.3   582.6   717.6   528.2
# 2015  509.7   549.8   521.9   458.3   529.0   452.8
# 2016  420.9   451.6   605.8   469.7   506.6   483.8
# 2017  430.3   404.6   520.5   403.7   428.5   466.7
# 2018  461.4   342.7   362.7   362.7   455.5   457.3
# 2019  474.8   398.1   468.2   443.8   459.3   459.3

# %%
df_CO2
# Out:
#        N-1-W  SS-2-W   S-1-W   S-2-W   S-1-P   S-2-P
# CO
# 2014  512.6   492.2   570.2   615.6   531.1   539.5
# 2015  522.0   508.8   598.2   551.0   530.5   548.6
# 2016  541.1   522.7   639.4   611.1   549.3   539.7
# 2017  542.5   521.7   599.2   597.6   529.2   528.1
# 2018  518.3   505.7   561.3   561.3   510.1   536.7
# 2019  479.2   503.8   549.0   563.5   526.7   531.5

# %%
df_NO2
# Out:
#       N-1-W SS-2-W  S-1-W  S-2-W  S-1-P  S-2-P
# CO
# 2014  39.8   34.1   45.7   40.0   39.2   47.9
# 2015  38.7   37.8   36.5   35.6   37.6   43.1
# 2016  42.0   39.1   37.7   41.1   39.8   47.4
# 2017  38.2   45.3   40.8   42.8   42.5   45.7
# 2018  34.7   34.9   37.1   37.1   42.7   43.5
# 2019  31.7   31.5   37.0   37.6   34.2   37.6

# %%
df_PM10
# Out:
#       N-1-W SS-2-W  S-1-W  S-2-W  S-1-P  S-2-P
# CO
# 2014  48.9   39.4   57.7   47.4   53.1   51.1
# 2015  51.3   37.5   51.9   48.0   55.2   46.0
# 2016  43.5   32.3   47.3   44.3   51.2   39.9
# 2017  39.2   31.3   43.8   39.1   42.3   36.3
# 2018  42.3   29.7   37.4   37.4   37.0   31.9
# 2019  38.5   33.7   40.5   38.1   37.0   33.7

# %%
df_PM25
# Out:
#       N-1-W SS-2-W  S-1-W  S-2-W  S-1-P  S-2-P
# CO
# 2014  24.9   21.3   34.3   30.9   28.8   24.7
# 2015  25.7   22.1   30.1   27.9   26.6   23.6
# 2016  24.1   16.5   27.0   28.7   29.7   30.1
# 2017  24.3   13.8   27.9   23.2   23.3   24.3
# 2018  25.8   19.0   23.6   23.6   20.4   22.5
# 2019  25.4   21.0   20.1   20.3   20.1   18.8

# %%
df_CO = df_CO.apply(pd.to_numeric, errors='coerce')
df_CO2 = df_CO2.apply(pd.to_numeric, errors='coerce')
df_NO2 = df_NO2.apply(pd.to_numeric, errors='coerce')
df_PM25 = df_PM25.apply(pd.to_numeric, errors='coerce')
df_PM10 = df_PM10.apply(pd.to_numeric, errors='coerce')

# %%
plt.figure(figsize=(20,5))
df_CO.plot(marker='o')

# %%
df_CO.plot(figsize=(16,8), marker ='o',ylim=[0,800],title='CO')
df_CO2.plot(figsize=(16,8), marker ='o',ylim=[0,800],title='CO2')
df_NO2.plot(figsize=(16,8), marker ='o',title='NO2',ylim=[0,60])
df_PM10.plot(figsize=(16,8), marker ='o',title='PM10',ylim=[0,70])
df_PM25.plot(figsize=(16,8), marker ='o',title='PM2.5',ylim=[0,50])

# %%
df_CO = df.iloc[0:6,6]
df_CO2 = df.iloc[7:13,6]
df_NO2 = df.iloc[14:20,6]
df_PM10 = df.iloc[21:27,6]
df_PM25 = df.iloc[28:34,6]

# %%
df_CO = df_CO.apply(pd.to_numeric, errors='coerce')
df_CO2 = df_CO2.apply(pd.to_numeric, errors='coerce')
df_NO2 = df_NO2.apply(pd.to_numeric, errors='coerce')
df_PM25 = df_PM25.apply(pd.to_numeric, errors='coerce')
df_PM10 = df_PM10.apply(pd.to_numeric, errors='coerce')
#

# %%
# df_CO.plot(figsize=(20,8), marker ='o',ylim=[300,800],title='CO')
# df_CO2.plot(figsize=(20,8), marker ='o',ylim=[300,800],title='CO2')
# df_NO2.plot(figsize=(20,8), marker ='o',title='NO2')
# df_PM10.plot(figsize=(20,8), marker ='o',title='PM10')
df_PM25.plot(figsize=(20,8), marker ='o',title='PM2.5',ylim=[0,40])

# %%
df_PM10.plot(figsize=(20,8), marker ='o',title='PM10',ylim=[0,60])

# %%
df_PM25.plot(figsize=(20,8), marker ='o',title='PM2.5',ylim=[0,30])
# ,ylim=[20,50]

# %%
df_NO2.plot(figsize=(20,8), marker ='o',title='NO2',ylim=[0,50])

# %%
df_CO2.plot(figsize=(20,8), marker ='o',ylim=[0,800],title='CO2')

# %%
df_CO.plot(figsize=(20,8), marker ='o',ylim=[0,800],title='CO')

# %% [markdown]
# #### 총지름 2.5마이크로 미터 이하가 초미세먼지, 10~2.5 사이가 미세먼지

# %%
df2 = pd.read_csv('C:/codeit/200512_지하철hcho.csv',index_col = 0, encoding = 'cp949')
df2
# Out:
#       N-1-W  SS-2-W  S-2-W  HCHO.1
# HCHO
# 2014    8.7     7.0   10.0     8.6
# 2015    7.9     7.9    6.1     7.3
# 2016   17.8     7.0    5.6    10.1
# 2017    8.2     7.5    6.4     7.4
# 2018    6.8     7.6    2.7     5.7
# 2019    3.9     6.6    1.9     4.2

# %%
df2['HCHO.1'].plot(figsize=(20,8), marker='o',title='HCHO',ylim=[0,12])

# %%
df2 = df2.loc[:,['N-1-W','SS-2-W','S-2-W']]
df2.plot(figsize=(20,8), marker='o',title='HCHO',ylim=[0,20])

# %% [markdown]
# # 1차적인 데이터 정제 이후 그래프 생성

# %% [markdown]
# # 2차 데이터 정제: 이상값 제거
# ## 그 외?

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
example_plot(ax4)
plt.tight_layout()


출처: https://ljs93kr.tistory.com/61 [건프의 소소한 개발이야기]

# %%
fig, ((ax1, ax2), (ax5, ax4),(ax3,ax6)) = plt.subplots(nrows=3, ncols=2)
fig.set_size_inches(18,14)

plt.tight_layout()
df_CO.plot(marker ='o',ylim=[0,800],title='CO', ax = ax1)
df_CO2.plot(marker ='o',ylim=[0,800],title='CO2',ax= ax2)
df_NO2.plot(marker ='o',title='NO2',ylim=[0,60],ax=ax3)
df_PM10.plot(marker ='o',title='PM10',ylim=[0,70],ax=ax4)
df_PM25.plot(marker ='o',title='PM2.5',ylim=[0,50],ax=ax5)
df2.plot(marker='o',title='HCHO',ylim=[0,20],ax =ax6)

# %%
fig, ((ax1, ax2), (ax3, ax4),(ax5,ax6)) = plt.subplots(nrows=3, ncols=2)
fig.set_size_inches(18,14)
plt.tight_layout()
df_CO.plot(marker ='o',ylim=[0,800],title='CO', ax = ax1)
df_CO2.plot(marker ='o',ylim=[0,800],title='CO2', ax = ax2)
df_PM25.plot(marker ='o',title='PM2.5',ylim=[0,40], ax = ax3)
df_PM10.plot(marker ='o',title='PM10',ylim=[0,60], ax = ax4)
df_NO2.plot(marker ='o',title='NO2',ylim=[0,50], ax = ax5)
df2['HCHO.1'].plot(marker='o',title='HCHO',ylim=[0,12], ax = ax6)
