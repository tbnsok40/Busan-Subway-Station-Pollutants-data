# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 12
plt.rcParams["font.weight"] = 'bold'


nampo = pd.read_csv('사상.csv', encoding = 'cp949')
nampo
# Out:
#        year  month  day  hour  CO (ppm)  CO2 (ppm)  NO2 (ppm)  PM2.5 (μg/m³)  \
# 0      2019      1    1     0       0.4      413.0      0.025           21.0
# 1      2019      1    1     1       0.3      407.0      0.025           20.0
# 2      2019      1    1     2       0.3      394.0      0.013           20.0
# 3      2019      1    1     3       0.3      396.0      0.013           27.0
# 4      2019      1    1     4       0.3      393.0      0.010           18.0
# ...     ...    ...  ...   ...       ...        ...        ...            ...
# 52579  2014     12   31    19       1.0      569.0      0.041            NaN
# 52580  2014     12   31    20       1.0      540.0      0.042            NaN
# 52581  2014     12   31    21       0.7      515.0      0.038            NaN
# 52582  2014     12   31    22       0.7      492.0      0.033            NaN
# 52583  2014     12   31    23       0.7      466.0      0.028            NaN
#
#        PM10 (μg/m³)  HCHO (ppm)
# 0              28.0         NaN
# 1              30.0         NaN
# 2              26.0         NaN
# 3              28.0         NaN
# 4              34.0         NaN
# ...             ...         ...
# 52579          32.0         8.0
# 52580          33.0         7.2
# 52581          28.0         6.3
# 52582          27.0         7.2
# 52583          17.0         6.4
#
# [52584 rows x 10 columns]

# %%
def automate_alltime(df):
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM10 (μg/m³)", data=df, ax= ax1, color = 'w')
    ax1.set(ylim=(-10, 300)) ## 750위로 9개 점(5개년에 걸쳐)
    plt.show()

    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM2.5 (μg/m³)", data=df, ax= ax1, color = 'w')
    ax1.set(ylim=(-10, 200)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    return

def automate_separate(df):
    
    df['OP'] = 'OP'
    df.loc[(df['hour']<=5)&(df['hour']>=1), 'OP'] = 'NON'
    
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)

    sns.boxplot(x="year", y="PM10 (μg/m³)", data=nampo, ax= ax1, hue = nampo['OP'])
    ax1.set(ylim=(-10, 300)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    
    
    fig, (ax1) = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(18,10)
    sns.boxplot(x="year", y="PM2.5 (μg/m³)", data=nampo, ax= ax1, hue = nampo['OP'])
    ax1.set(ylim=(-10, 200)) ## 800위로 12개 점 (5개년에 걸쳐)

    plt.show()
    
 
    return

automate_alltime(nampo)
automate_separate(nampo)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# plt.title("요일 별 전체 팁의 Box Plot")
fig, (ax1) = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(18,10)
sns.boxplot(x="datetime-year", y="PM10", data=nampo, ax= ax1)
ax1.set(ylim=(-10, 300)) # 400 위로 2점 찍힘(2015년)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# plt.title("요일 별 전체 팁의 Box Plot")
fig, (ax1) = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(18,10)
sns.boxplot(x="datetime-year", y="PM2.5", data=nampo, ax= ax1)
ax1.set(ylim=(-10, 200))


plt.show()
