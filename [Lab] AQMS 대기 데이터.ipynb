# %%
import pandas as pd
import matplotlib as pyplot
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns

# 그거, 메모장 파일경로 알려준다.
# import matplotlib
# matplotlib.matplotlib_fname()

# %%
import pandas as pd

광복 = pd.read_csv('C:/Users/User/jupyternotebook/LAB/시계열/광복동.csv')
학장 = pd.read_csv('C:/Users/User/jupyternotebook/LAB/시계열/학장동.csv')
전포 = pd.read_csv('C:/Users/User/jupyternotebook/LAB/시계열/전포동.csv')
온천 = pd.read_csv('C:/Users/User/jupyternotebook/LAB/시계열/온천동.csv', encoding = 'utf-8')
전포['풍향'].value_counts()
# Out:
# 북서     6414
# 남남서    5840
# 남      4264
# 서북서    4217
# 북북서    3828
# 남서     3610
# 동      3300
# 서      3227
# 서남서    2765
# 동북동    2408
# 동남동    2308
# 북동     2287
# 북      1829
# 점검     1789
# 남동     1726
# 북북동    1545
# 남남동    1454
# 중단      140
# 동불       29
# 전단       21
# Name: 풍향, dtype: int64

# %%
온천=온천.apply(pd.to_numeric, errors='coerce')
학장=학장.apply(pd.to_numeric, errors='coerce')
전포=전포.apply(pd.to_numeric, errors='coerce')
광복=광복.apply(pd.to_numeric, errors='coerce')

# %%
# 온천=온천.drop(['풍향','측정소'],axis=1)
온천[['CO','NO₂']]= 온천[['CO','NO₂']]*1000
학장[['CO','NO₂']]= 학장[['CO','NO₂']]*1000
광복[['CO','NO₂']]= 광복[['CO','NO₂']]*1000
전포[['CO','NO₂']]= 전포[['CO','NO₂']]*1000

# %% [markdown]
# # 온천

# %%
# print(온천.loc[2014]['CO'].mean())
# print(온천.loc[2015]['CO'].mean())
# print(온천.loc[2016]['CO'].mean())
# print(온천.loc[2017]['CO'].mean())
# print(온천.loc[2018]['CO'].mean())
# print(온천.loc[2019]['CO'].mean())
# print(온천.loc[2014]['NO₂'].mean())
# print(온천.loc[2015]['NO₂'].mean())
# print(온천.loc[2016]['NO₂'].mean())
# print(온천.loc[2017]['NO₂'].mean())
# print(온천.loc[2018]['NO₂'].mean())
# print(온천.loc[2019]['NO₂'].mean())
# print(온천.loc[2014]['PM10'].mean())
# print(온천.loc[2015]['PM10'].mean())
# print(온천.loc[2016]['PM10'].mean())
# print(온천.loc[2017]['PM10'].mean())
# print(온천.loc[2018]['PM10'].mean())
# print(온천.loc[2019]['PM10'].mean())
# print(온천.loc[2014]['PM2.5'].mean())
# print(온천.loc[2015]['PM2.5'].mean())
# print(온천.loc[2016]['PM2.5'].mean())
# print(온천.loc[2017]['PM2.5'].mean())
# print(온천.loc[2018]['PM2.5'].mean())
# print(온천.loc[2019]['PM2.5'].mean())

# %% [markdown]
# # 전포

# %%
# print(전포.loc[2014]['CO'].mean())
# print(전포.loc[2015]['CO'].mean())
# print(전포.loc[2016]['CO'].mean())
# print(전포.loc[2017]['CO'].mean())
# print(전포.loc[2018]['CO'].mean())
# print(전포.loc[2019]['CO'].mean())
# print(전포.loc[2014]['NO₂'].mean())
# print(전포.loc[2015]['NO₂'].mean())
# print(전포.loc[2016]['NO₂'].mean())
# print(전포.loc[2017]['NO₂'].mean())
# print(전포.loc[2018]['NO₂'].mean())
# print(전포.loc[2019]['NO₂'].mean())
# print(전포.loc[2014]['PM10'].mean())
# print(전포.loc[2015]['PM10'].mean())
# print(전포.loc[2016]['PM10'].mean())
# print(전포.loc[2017]['PM10'].mean())
# print(전포.loc[2018]['PM10'].mean())
# print(전포.loc[2019]['PM10'].mean())
# print(전포.loc[2014]['PM2.5'].mean())
# print(전포.loc[2015]['PM2.5'].mean())
# print(전포.loc[2016]['PM2.5'].mean())
# print(전포.loc[2017]['PM2.5'].mean())
# print(전포.loc[2018]['PM2.5'].mean())
# print(전포.loc[2019]['PM2.5'].mean())

# %% [markdown]
# # 학장

# %%
# print(학장.loc[2015]['CO'].mean())
# print(학장.loc[2014]['CO'].mean())
# print(학장.loc[2016]['CO'].mean())
# print(학장.loc[2017]['CO'].mean())
# print(학장.loc[2018]['CO'].mean())
# print(학장.loc[2019]['CO'].mean())
# print(학장.loc[2014]['NO₂'].mean())
# print(학장.loc[2015]['NO₂'].mean())
# print(학장.loc[2016]['NO₂'].mean())
# print(학장.loc[2017]['NO₂'].mean())
# print(학장.loc[2018]['NO₂'].mean())
# print(학장.loc[2019]['NO₂'].mean())
# print(학장.loc[2014]['PM10'].mean())
# print(학장.loc[2015]['PM10'].mean())
# print(학장.loc[2016]['PM10'].mean())
# print(학장.loc[2017]['PM10'].mean())
# print(학장.loc[2018]['PM10'].mean())
# print(학장.loc[2019]['PM10'].mean())
# print(학장.loc[2014]['PM2.5'].mean())
# print(학장.loc[2015]['PM2.5'].mean())
# print(학장.loc[2016]['PM2.5'].mean())
# print(학장.loc[2017]['PM2.5'].mean())
# print(학장.loc[2018]['PM2.5'].mean())
# print(학장.loc[2019]['PM2.5'].mean())

# %% [markdown]
# # 광복

# %%
# print(광복.loc[2014]['CO'].mean())
# print(광복.loc[2015]['CO'].mean())
# print(광복.loc[2016]['CO'].mean())
# print(광복.loc[2017]['CO'].mean())
# print(광복.loc[2018]['CO'].mean())
# print(광복.loc[2019]['CO'].mean())
# print(광복.loc[2014]['NO₂'].mean())
# print(광복.loc[2015]['NO₂'].mean())
# print(광복.loc[2016]['NO₂'].mean())
# print(광복.loc[2017]['NO₂'].mean())
# print(광복.loc[2018]['NO₂'].mean())
# print(광복.loc[2019]['NO₂'].mean())
# print(광복.loc[2014]['PM10'].mean())
# print(광복.loc[2015]['PM10'].mean())
# print(광복.loc[2016]['PM10'].mean())
# print(광복.loc[2017]['PM10'].mean())
# print(광복.loc[2018]['PM10'].mean())
# print(광복.loc[2019]['PM10'].mean())
# print(광복.loc[2014]['PM2.5'].mean())
# print(광복.loc[2015]['PM2.5'].mean())
# print(광복.loc[2016]['PM2.5'].mean())
# print(광복.loc[2017]['PM2.5'].mean())
# print(광복.loc[2018]['PM2.5'].mean())
# print(광복.loc[2019]['PM2.5'].mean())

# %% [markdown]
# # 4개 동 년도별 그래프 (all time)

# %%
온천 = 온천.rename({'년':'year'}, axis='columns')
광복 = 광복.rename({'년':'year'}, axis='columns')
학장 = 학장.rename({'년':'year'}, axis='columns')
전포 = 전포.rename({'년':'year'}, axis='columns')

# %% [markdown]
# # 광복

# %%
광복['풍향']
# Out:
#        측정소  year  월   일   시     CO   NO₂   PM10  PM2.5  풍향   풍속
# 0      NaN  2014  1   1   1  600.0  23.0  129.0    NaN NaN  1.8
# 1      NaN  2014  1   1   2  600.0  23.0  135.0    NaN NaN  1.3
# 2      NaN  2014  1   1   3  500.0  17.0  132.0    NaN NaN  2.1
# 3      NaN  2014  1   1   4  500.0  18.0  146.0    NaN NaN  2.1
# 4      NaN  2014  1   1   5  500.0  19.0  145.0    NaN NaN  1.7
# ...    ...   ... ..  ..  ..    ...   ...    ...    ...  ..  ...
# 53323  NaN  2020  1  31  20  500.0  32.0   33.0   19.0 NaN  0.5
# 53324  NaN  2020  1  31  21  500.0  33.0   37.0   25.0 NaN  0.4
# 53325  NaN  2020  1  31  22  500.0  33.0   35.0   23.0 NaN  0.6
# 53326  NaN  2020  1  31  23  400.0  30.0   37.0   19.0 NaN  0.9
# 53327  NaN  2020  1  31  24  400.0  19.0   31.0   19.0 NaN  0.9
#
# [53328 rows x 11 columns]

# %%
# from matplotlib import font_manager, rc
# font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/Times.ttf").get_name()
# rc('font', family=font_name)

sns.set_style({'font.family':'serif', 'font.serif':['Times New Roman']})


figure, ((ax1,ax2,ax3,ax4)) = plt.subplots(nrows=4, ncols=1)

figure.set_size_inches(15,25)
sns.lineplot(data=광복, x='year', y = 'CO', ax = ax1)
sns.lineplot(data=광복, x='year', y = 'NO₂', ax = ax2)
sns.lineplot(data=광복, x='year', y = 'PM2.5', ax = ax3)
sns.lineplot(data=광복, x='year', y = 'PM10', ax = ax4)

plt.show()

# 차라리 노골적이고 단순한 야망과 욕심에 끌린다
# 그 모습이 조금은 귀여워 보일 수 있다면 금상첨와

# %% [markdown]
# # 전포

# %%
# from matplotlib import font_manager, rc
# font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/Times.ttf").get_name()
# rc('font', family=font_name)

sns.set_style({'font.family':'serif', 'font.serif':['Times New Roman']})


figure, ((ax1,ax2,ax3,ax4)) = plt.subplots(nrows=4, ncols=1)

figure.set_size_inches(15,25)
sns.lineplot(data=전포, x='year', y = 'CO', ax = ax1)
sns.lineplot(data=전포, x='year', y = 'NO₂', ax = ax2)
sns.lineplot(data=전포, x='year', y = 'PM2.5', ax = ax3)
sns.lineplot(data=전포, x='year', y = 'PM10', ax = ax4)

plt.show()

# 차라리 노골적이고 단순한 야망과 욕심에 끌린다
# 그 모습이 조금은 귀여워 보일 수 있다면 금상첨와

# %% [markdown]
# # 학장

# %%
# from matplotlib import font_manager, rc
# font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/Times.ttf").get_name()
# rc('font', family=font_name)

sns.set_style({'font.family':'serif', 'font.serif':['Times New Roman']})


figure, ((ax1,ax2,ax3,ax4)) = plt.subplots(nrows=4, ncols=1)

figure.set_size_inches(15,25)
sns.lineplot(data=학장, x='year', y = 'CO', ax = ax1)
sns.lineplot(data=학장, x='year', y = 'NO₂', ax = ax2)
sns.lineplot(data=학장, x='year', y = 'PM2.5', ax = ax3)
sns.lineplot(data=학장, x='year', y = 'PM10', ax = ax4)

plt.show()

# 차라리 노골적이고 단순한 야망과 욕심에 끌린다
# 그 모습이 조금은 귀여워 보일 수 있다면 금상첨와

# %% [markdown]
# # 온천

# %%
# from matplotlib import font_manager, rc
# font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/Times.ttf").get_name()
# rc('font', family=font_name)

sns.set_style({'font.family':'serif', 'font.serif':['Times New Roman']})


figure, ((ax1,ax2,ax3,ax4)) = plt.subplots(nrows=4, ncols=1)

figure.set_size_inches(15,25)
sns.lineplot(data=온천, x='year', y = 'CO', ax = ax1)
sns.lineplot(data=온천, x='year', y = 'NO₂', ax = ax2)
sns.lineplot(data=온천, x='year', y = 'PM2.5', ax = ax3)
sns.lineplot(data=온천, x='year', y = 'PM10', ax = ax4)

plt.show()

# 차라리 노골적이고 단순한 야망과 욕심에 끌린다
# 그 모습이 조금은 귀여워 보일 수 있다면 금상첨와

# %%
온천
# Out:
#        측정소  year  월   일   시      CO   NO₂   PM10  PM2.5  풍향   풍속
# 0      NaN  2014  1   1   1  1100.0  15.0   96.0    NaN NaN  1.8
# 1      NaN  2014  1   1   2   900.0  14.0  101.0    NaN NaN  1.9
# 2      NaN  2014  1   1   3   800.0  12.0  104.0    NaN NaN  2.1
# 3      NaN  2014  1   1   4   800.0  12.0  119.0    NaN NaN  1.8
# 4      NaN  2014  1   1   5   800.0  11.0  128.0    NaN NaN  2.0
# ...    ...   ... ..  ..  ..     ...   ...    ...    ...  ..  ...
# 53323  NaN  2020  1  31  20   500.0  40.0   31.0   26.0 NaN  0.8
# 53324  NaN  2020  1  31  21   500.0  34.0   41.0   27.0 NaN  0.3
# 53325  NaN  2020  1  31  22   500.0  34.0   32.0   26.0 NaN  0.2
# 53326  NaN  2020  1  31  23   600.0  38.0   32.0   26.0 NaN  0.3
# 53327  NaN  2020  1  31  24   600.0  35.0   33.0   30.0 NaN  0.4
#
# [53328 rows x 11 columns]

# %%
전포
# Out:
#        측정소  year  월   일   시     CO   NO₂   PM10  PM2.5  풍향   풍속
# 0      NaN  2014  1   1   1  400.0  16.0   94.0    NaN NaN  2.5
# 1      NaN  2014  1   1   2  400.0  15.0  103.0    NaN NaN  2.0
# 2      NaN  2014  1   1   3  400.0  16.0  109.0    NaN NaN  2.3
# 3      NaN  2014  1   1   4  400.0  16.0  113.0    NaN NaN  2.2
# 4      NaN  2014  1   1   5  400.0  17.0  131.0    NaN NaN  2.2
# ...    ...   ... ..  ..  ..    ...   ...    ...    ...  ..  ...
# 53323  NaN  2020  1  31  20  500.0  48.0   36.0   27.0 NaN  0.5
# 53324  NaN  2020  1  31  21  500.0  46.0   44.0   26.0 NaN  0.4
# 53325  NaN  2020  1  31  22  400.0  39.0   37.0   25.0 NaN  0.7
# 53326  NaN  2020  1  31  23  500.0  41.0   40.0   23.0 NaN  0.7
# 53327  NaN  2020  1  31  24  500.0  42.0   34.0   26.0 NaN  0.4
#
# [53328 rows x 11 columns]

# %%
# 온천['time'] = pd.date_range(start = '2014-1-1-1',end = '2020-1-31-24', freq = 'H')

# %% [markdown]
# ### 시간 부분에 01로 안해주고 1로 하면 자꾸 오류남!!
# ### dataframe의 인덱스 확인하면서, time frame이 들어갈 개수 계산해야 오류 안난다

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime


온천 = pd.read_csv('C:/Users/User/jupyternotebook/LAB/시계열/온천동_.csv')
# pd.date_range(start = "2014-1-1", end='2020-1-31-24', freq = 'H')
# time = pd.date_range("2014-1-1-1", "2020-1-31-24", freq='H')
# time
온천['time']=pd.date_range(start='2014-1-1-01', end='2020-2-1-00', freq = 'H')
온천
# Out:
#                      time   CO    NO₂ PM10 PM2.5   풍속
# 0     2014-01-01 01:00:00  1.1  0.015   96   NaN  1.8
# 1     2014-01-01 02:00:00  0.9  0.014  101   NaN  1.9
# 2     2014-01-01 03:00:00  0.8  0.012  104   NaN  2.1
# 3     2014-01-01 04:00:00  0.8  0.012  119   NaN  1.8
# 4     2014-01-01 05:00:00  0.8  0.011  128   NaN    2
# ...                   ...  ...    ...  ...   ...  ...
# 53323 2020-01-31 20:00:00  0.5   0.04   31    26  0.8
# 53324 2020-01-31 21:00:00  0.5  0.034   41    27  0.3
# 53325 2020-01-31 22:00:00  0.5  0.034   32    26  0.2
# 53326 2020-01-31 23:00:00  0.6  0.038   32    26  0.3
# 53327 2020-02-01 00:00:00  0.6  0.035   33    30  0.4
#
# [53328 rows x 6 columns]

# %%
온천["time-year"] = 온천["time"].dt.year
온천["time-month"] = 온천["time"].dt.month
온천["time-day"] = 온천["time"].dt.day
온천["time-hour"] = 온천["time"].dt.hour

# %%
# 온천14 = 온천.loc[온천['time-year']==2014]

# %%
온천non= (온천['time-hour']<=23) & (온천['time-hour']>=5)
온천op= (온천['time-hour']>=0) & (온천['time-hour']<5)

# %%
# 온천['CO']=온천['CO'].apply(pd.to_numeric, errors='coerce')
# 온천['NO₂']=온천['NO₂'].apply(pd.to_numeric, errors='coerce')
# 온천['PM10']=온천['PM10'].apply(pd.to_numeric, errors='coerce')
# 온천['PM2.5']=온천['PM2.5'].apply(pd.to_numeric, errors='coerce')


# figure, (ax1) = plt.subplots(nrows=1, ncols=1)
# figure.set_size_inches(18,10)
# sns.lineplot(data=온천, x='time-hour', y = 'CO', ax = ax1, ci=None, hue = 온천['OP'])
# # sns.lineplot(data=온천, x='time-hour', y = 'NO₂', ax = ax2)
# # sns.lineplot(data=온천, x='time-hour', y = 'PM10', ax = ax3)
# # sns.lineplot(data=온천, x='time-hour', y = 'PM2.5', ax = ax4)

# %%
# 온천op = 온천.loc[온천op]
온천non = 온천.loc[온천non]
# 온천non

# %%
온천non['CO']=온천non['CO'].apply(pd.to_numeric, errors='coerce')
온천non['NO₂']=온천non['NO₂'].apply(pd.to_numeric, errors='coerce')
온천non['PM10']=온천non['PM10'].apply(pd.to_numeric, errors='coerce')
온천non['PM2.5']=온천non['PM2.5'].apply(pd.to_numeric, errors='coerce')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
import seaborn as sns
figure, (ax1,ax2,ax3,ax4) = plt.subplots(nrows=4, ncols=1)
figure.set_size_inches(18,30)
sns.lineplot(data=온천non, x='time-year', y = 'CO', ax = ax1, ci=None)
sns.lineplot(data=온천non, x='time-year', y = 'NO₂', ax = ax2, ci=None)
sns.lineplot(data=온천non, x='time-year', y = 'PM10', ax = ax3, ci=None)
sns.lineplot(data=온천non, x='time-year', y = 'PM2.5', ax = ax4, ci=None)

# %% [markdown]
# ## (할 일)주말, 평일 나누기

# %%
온천non
# Out:
#                      time   CO    NO₂   PM10  PM2.5   풍속  time-year  \
# 4     2014-01-01 05:00:00  0.8  0.011  128.0    NaN    2       2014
# 5     2014-01-01 06:00:00  0.7  0.014  117.0    NaN  1.5       2014
# 6     2014-01-01 07:00:00  0.6  0.016  127.0    NaN  1.4       2014
# 7     2014-01-01 08:00:00  0.5  0.017  127.0    NaN  1.4       2014
# 8     2014-01-01 09:00:00  0.6  0.018  132.0    NaN  1.2       2014
# ...                   ...  ...    ...    ...    ...  ...        ...
# 53322 2020-01-31 19:00:00  0.5  0.029   27.0   15.0  0.2       2020
# 53323 2020-01-31 20:00:00  0.5  0.040   31.0   26.0  0.8       2020
# 53324 2020-01-31 21:00:00  0.5  0.034   41.0   27.0  0.3       2020
# 53325 2020-01-31 22:00:00  0.5  0.034   32.0   26.0  0.2       2020
# 53326 2020-01-31 23:00:00  0.6  0.038   32.0   26.0  0.3       2020
#
#        time-month  time-day  time-hour
# 4               1         1          5
# 5               1         1          6
# ...

# %%
# 온천= 온천.set_index("time-year")

# 온천1415['CO']=온천1415['CO'].apply(pd.to_numeric, errors='coerce')
# 온천non['CO']=온천non['CO'].apply(pd.to_numeric, errors='coerce')

온천non['풍속'] = 온천non['풍속'].apply(pd.to_numeric, errors= 'coerce')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # 풍속과의 관계

# %%
print(온천non.loc[온천non['time-year'] == 2016]['풍속'].mean())
print(온천non.loc[온천non['time-year'] == 2018]['풍속'].mean())
print(온천non.loc[온천non['time-year'] == 2019]['풍속'].mean())

# pm2.5는 풍속의 영향이 없더.

# 온천non
# Out:
# 1.6792672288455885
# 0.9428550074738331
# 0.759697188175918

# %%
# figure, (ax1) = plt.subplots(nrows=4, ncols=1)
# figure.set_size_inches(18,30)
# sns.barplot(data=온천1415, x="time-year_month", y="CO", ax=ax1)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")

# %%
fmri['timepoint'].unique()
# Out:
# array([18, 14, 17,  9, 16, 15,  0, 13, 12, 11, 10,  3,  7,  8,  2,  6,  5,
#         4,  1], dtype=int64)

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]
